# %%
import scipy
import numpy as np
import pandas as pd
import seaborn as sns
import seaborn.objects as so

# Para clustering
from sklearn.datasets import make_blobs
from sklearn.datasets import make_circles
from sklearn.preprocessing import StandardScaler 
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN

# %%
penguins = sns.load_dataset("penguins").dropna().reset_index(drop=True)
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen            36.7           19.3              193.0
# 4  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3       3450.0  Female
# 4       3650.0    Male

# %%
(
    so.Plot(data = penguins, x = "bill_length_mm", y = "bill_depth_mm", color = "species")
    .add(so.Dot(color = "red"), data = penguins.iloc[[10]])
    .add(so.Dot(), data = penguins.drop([10, 313, 151]))
    #.add(so.Text(), text = penguins.index)
)

# %%
(
    so.Plot(data = penguins, x = "bill_length_mm", y = "bill_depth_mm", color = "species")
    .add(so.Dot(color = "red"), data = penguins.iloc[[313]])
    .add(so.Dot(), data = penguins.drop([313,151]))   
)

# %%
(
    so.Plot(data = penguins, x = "bill_length_mm", y = "bill_depth_mm", color = "species")
    .add(so.Dot(color = "red"), data = penguins.iloc[[151]])
    .add(so.Dot(), data = penguins.drop([151]))   
)
